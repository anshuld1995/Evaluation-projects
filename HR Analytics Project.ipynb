# %% [markdown]
# # HR Analytics Project Problem Statement

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# HR Analytics Project
# Problem Statement:
#
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# Attrition in HR
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# Attrition affecting Companies
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.#

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# We see that there are 34 types of data for determining "attraction" and 1470 data for each column.

# %%
# Checking for info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# We see that 9 columns have data objective type and others are integer type

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
print(df["Age"].value_counts())
plt.figure(figsize=(20,12))
sns.histplot(df['Age'],bins=50)
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
#  Maximum age of the given data content between 35 and 40

# %%
print(df["Attrition"].value_counts())
sns.countplot(df["Attrition"])
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# e see that the number of no(1233) is greter than number of yes(237) in the "Attrition" column of the given hr analysis project.So,class is imbalanced

# %%
#to change the non-numeric data to numeric data of 'Attrition' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Attrition']=le.fit_transform(df['Attrition']).astype(float)

# %%
print(df["Attrition"].value_counts())
# Out:
# 0.0    1233
# 1.0     237
# Name: Attrition, dtype: int64

# %%
print(df["BusinessTravel"].value_counts())
sns.countplot(df["BusinessTravel"])
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# we see that there are three types of non numeric data in "BusinessTravel" column and class is imbalanced.

# %%
#to change the non-numeric data to numeric data of 'BusinessTravel' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['BusinessTravel']=le.fit_transform(df['BusinessTravel']).astype(float)

# %%
print(df["BusinessTravel"].value_counts())
# Out:
# 2.0    1043
# 1.0     277
# 0.0     150
# Name: BusinessTravel, dtype: int64

# %%
print(df["Department"].value_counts())
sns.countplot(df["Department"])
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
print(df["Department"].value_counts())
sns.countplot(df["Department"])
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
#to change the non-numeric data to numeric data of 'Department' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Department']=le.fit_transform(df['Department']).astype(float)

# %%
print(df["Department"].value_counts())
# Out:
# 1.0    961
# 2.0    446
# 0.0     63
# Name: Department, dtype: int64

# %%
print(df["DistanceFromHome"].value_counts())
plt.figure(figsize=(20,12))
sns.countplot(df["DistanceFromHome"])
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %% [markdown]
# we see that there are 29 types of data in "DistanceFromHome" column and class is also imbalanced

# %%
print(df["Education"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["Education"])
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# we see that there are 5 types of data in "Education" column of the dataframe and class is also imbalanced

# %%
print(df["EducationField"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["EducationField"])
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# we see that there are 6 types of data in "Education" column of the dataframe and class is also imbalanced

# %%
#to change the non-numeric data to numeric data of 'EducationField' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['EducationField']=le.fit_transform(df['EducationField']).astype(float)

# %%
print(df["EducationField"].value_counts())
# Out:
# 1.0    606
# 3.0    464
# 2.0    159
# 5.0    132
# 4.0     82
# 0.0     27
# Name: EducationField, dtype: int64

# %%
print(df["EmployeeCount"].value_counts())
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# we see from the above code there is only one type value in the "EmployeeCount" column.so,we can drop this column.

# %%
#drop "EmployeeCount" column
df=df.drop("EmployeeCount",axis=1)

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41        1.0             2.0       1102         2.0                 1
# 1   49        0.0             1.0        279         1.0                 8
# 2   37        1.0             2.0       1373         1.0                 2
# 3   33        0.0             1.0       1392         1.0                 3
# 4   27        0.0             2.0        591         1.0                 2
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0          2             1.0               1                        2  ...
# 1          1             1.0               2                        3  ...
# 2          2             4.0               4                        4  ...
# 3          4             1.0               5                        4  ...
# 4          1             3.0               7                        1  ...
#
#   RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                        1             80                 0
# 1                        4             80                 1
# 2                        2             80                 0
# 3                        3             80                 0
# 4                        4             80                 1
#
#    TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                  8                     0                1              6
# 1                 10                     3                3             10
# 2                  7                     3                3              0
# 3                  8                     3                3              8
# 4                  6                     3                3              2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 34 columns]

# %%
print(df["EmployeeNumber"].value_counts())
# Out:
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %% [markdown]
# We see that the column "EmployeeNumber" refers to only one number.so,we can drop this column

# %%
df=df.drop("EmployeeNumber",axis=1)

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41        1.0             2.0       1102         2.0                 1
# 1   49        0.0             1.0        279         1.0                 8
# 2   37        1.0             2.0       1373         1.0                 2
# 3   33        0.0             1.0       1392         1.0                 3
# 4   27        0.0             2.0        591         1.0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2             1.0                        2  Female  ...
# 1          1             1.0                        3    Male  ...
# 2          2             4.0                        4    Male  ...
# 3          4             1.0                        4  Female  ...
# 4          1             3.0                        1    Male  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 33 columns]

# %%
print(df["EnvironmentSatisfaction"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["EnvironmentSatisfaction"])
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# we see that there are 4 types of data in "EnvironmentSatisfaction" column of the dataframe and class is also imbalanced

# %%
print(df["Gender"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["Gender"])
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# we see that there are 2 types of data in "Gender" column of the dataframe and class is also imbalanced

# %%
#to change the non-numeric data to numeric data of 'Gender' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender']).astype(float)

# %%
print(df["Gender"].value_counts())
# Out:
# 1.0    882
# 0.0    588
# Name: Gender, dtype: int64

# %%
df.iloc[:,10:20]
# Out:
#       HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 0             94               3         2            Sales Executive
# 1             61               2         2         Research Scientist
# 2             92               2         1      Laboratory Technician
# 3             56               3         1         Research Scientist
# 4             40               3         1      Laboratory Technician
# ...          ...             ...       ...                        ...
# 1465          41               4         2      Laboratory Technician
# 1466          42               2         3  Healthcare Representative
# 1467          87               4         2     Manufacturing Director
# 1468          63               2         2            Sales Executive
# 1469          82               4         2      Laboratory Technician
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                   4        Single           5993        19479
# 1                   2       Married           5130        24907
# 2                   3        Single           2090         2396
# 3                   3       Married           2909        23159
# 4                   2       Married           3468        16632
# ...               ...           ...            ...          ...
# 1465                4       Married           2571        12290
# 1466                1       Married           9991        21457
# 1467                2       Married           6142         5174
# 1468                2       Married           5390        13243
# 1469                3       Married           4404        10228
#
#       NumCompaniesWorked Over18
# 0                      8      Y
# 1                      1      Y
# 2                      6      Y
# 3                      1      Y
# 4                      9      Y
# ...                  ...    ...
# 1465                   4      Y
# 1466                   4      Y
# 1467                   1      Y
# 1468                   2      Y
# 1469                   2      Y
#
# [1470 rows x 10 columns]

# %%
print(df["HourlyRate"].value_counts())
plt.figure(figsize=(20,12))
sns.countplot(df["HourlyRate"])
# Out:
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64
# <AxesSubplot:xlabel='HourlyRate', ylabel='count'>

# %%
print(df["JobInvolvement"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["JobInvolvement"])
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# we see that there are 4 types of data in "JobInvolvement" column of the dataframe and class is also imbalanced

# %%
 print(df["JobLevel"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["JobLevel"])
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# we see that there are 5 types of data in "JobLevel" column of the dataframe and class is also imbalanced

# %%
print(df["JobRole"].value_counts())
plt.figure(figsize=(20,12))
sns.countplot(df["JobRole"])
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# e see that there are 9 types of data in "JobLevel" column of the dataframe and class is also imbalanced

# %%
#to change the non-numeric data to numeric data of 'JobRole' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['JobRole']=le.fit_transform(df['JobRole']).astype(float)

# %%
print(df["JobRole"].value_counts())
# Out:
# 7.0    326
# 6.0    292
# 2.0    259
# 4.0    145
# 0.0    131
# 3.0    102
# 8.0     83
# 5.0     80
# 1.0     52
# Name: JobRole, dtype: int64

# %%
print(df["JobSatisfaction"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["JobSatisfaction"])
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# we see that there are 4 types of data in "JobSatisfaction" column of the dataframe and class is also imbalanced

# %%
print(df["MaritalStatus"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["MaritalStatus"])
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# we see that there are 4 types of data in "MaritalStatus" column of the dataframe and class is also imbalanced

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df["MaritalStatus"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
#to change the non-numeric data to numeric data of 'JobRole' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['MaritalStatus']=le.fit_transform(df['MaritalStatus']).astype(float)

# %%
print(df["MaritalStatus"].value_counts())
# Out:
# 1.0    673
# 2.0    470
# 0.0    327
# Name: MaritalStatus, dtype: int64

# %%
print(df["NumCompaniesWorked"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["NumCompaniesWorked"])
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %% [markdown]
# we see that there are 10 types of data in "NumCompaniesWorked" column of the dataframe and class is also imbalanced.

# %%
print(df["Over18"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["Over18"])
# Out:
# Y    1470
# Name: Over18, dtype: int64
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %% [markdown]
# we see that there are only one types of data in "Over18" column of the dataframe.so,we drop this column

# %%
#droping "Over18" column
df=df.drop("Over18",axis=1)

# %%
df.iloc[:,10:20]
# Out:
#       HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# 0             94               3         2      7.0                4
# 1             61               2         2      6.0                2
# 2             92               2         1      2.0                3
# 3             56               3         1      6.0                3
# 4             40               3         1      2.0                2
# ...          ...             ...       ...      ...              ...
# 1465          41               4         2      2.0                4
# 1466          42               2         3      0.0                1
# 1467          87               4         2      4.0                2
# 1468          63               2         2      7.0                2
# 1469          82               4         2      2.0                3
#
#       MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime
# 0               2.0           5993        19479                   8      Yes
# 1               1.0           5130        24907                   1       No
# 2               2.0           2090         2396                   6      Yes
# 3               1.0           2909        23159                   1      Yes
# 4               1.0           3468        16632                   9       No
# ...             ...            ...          ...                 ...      ...
# 1465            1.0           2571        12290                   4       No
# 1466            1.0           9991        21457                   4       No
# 1467            1.0           6142         5174                   1      Yes
# 1468            1.0           5390        13243                   2       No
# 1469            1.0           4404        10228                   2       No
#
# [1470 rows x 10 columns]

# %%
print(df["OverTime"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["OverTime"])
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# We see that most employees do not work overtime.we also see that there are two type data in "OverTime" column and class is imbalanced

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df["OverTime"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# here 0.0--->Female and 1.0--->Male
#
# We see that the number of male employees is higher than the number of female employees in both overtime workers and non-overtime workers.

# %%
#to change the non-numeric data to numeric data of 'JobRole' column,we are using labelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['OverTime']=le.fit_transform(df['OverTime']).astype(float)

# %%
print(df["OverTime"].value_counts())
# Out:
# 0.0    1054
# 1.0     416
# Name: OverTime, dtype: int64

# %%
df.iloc[:,20:30]
# Out:
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                    11                  3                         1
# 1                    23                  4                         4
# 2                    15                  3                         2
# 3                    11                  3                         3
# 4                    12                  3                         4
# ...                 ...                ...                       ...
# 1465                 17                  3                         3
# 1466                 15                  3                         1
# 1467                 20                  4                         2
# 1468                 14                  3                         4
# 1469                 12                  3                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  8
# 1                80                 1                 10
# 2                80                 0                  7
# 3                80                 0                  8
# 4                80                 1                  6
# ...             ...               ...                ...
# 1465             80                 1                 17
# 1466             80                 1                  9
# 1467             80                 1                  6
# 1468             80                 0                 17
# 1469             80                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                1               6
# 1                         3                3              10
# 2                         3                3               0
# 3                         3                3               8
# 4                         3                3               2
# ...                     ...              ...             ...
# 1465                      3                3               5
# 1466                      5                3               7
# 1467                      0                3               6
# 1468                      3                2               9
# 1469                      3                4               4
#
#       YearsInCurrentRole
# 0                      4
# 1                      7
# 2                      0
# 3                      7
# 4                      2
# ...                  ...
# 1465                   2
# 1466                   7
# 1467                   2
# 1468                   6
# 1469                   3
#
# [1470 rows x 10 columns]

# %%
print(df["PercentSalaryHike"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["PercentSalaryHike"])
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %% [markdown]
# we see that there are 15 types of data in "PercentSalaryHike" column of the dataframe and class are also imbalanced

# %%
plt.figure(figsize=(20,7))
sns.countplot(x=df["PercentSalaryHike"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %%
print(df["PerformanceRating"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["PerformanceRating"])
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# we see that there are two types of data in 'PerformanceRating' column of our dataframe and class are imbalanced.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df["PerformanceRating"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# We see that the performance rating of male employees is always higher than that of female employees

# %%
print(df["RelationshipSatisfaction"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["RelationshipSatisfaction"])
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %% [markdown]
# we see that there are four types of data in 'RelationshipSatisfaction' column of our dataframe and class are imbalanced.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df["RelationshipSatisfaction"],hue=df["Gender"])
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %%
print(df["StandardHours"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["StandardHours"])
# Out:
# 80    1470
# Name: StandardHours, dtype: int64
# <AxesSubplot:xlabel='StandardHours', ylabel='count'>

# %% [markdown]
# we see that there are only one type values in "StandardHours" column which is 80.so,we can drop this column.

# %%
#droping "StandardHours" column
df=df.drop("StandardHours",axis=1)

# %%
df.iloc[:,20:30]
# Out:
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                    11                  3                         1
# 1                    23                  4                         4
# 2                    15                  3                         2
# 3                    11                  3                         3
# 4                    12                  3                         4
# ...                 ...                ...                       ...
# 1465                 17                  3                         3
# 1466                 15                  3                         1
# 1467                 20                  4                         2
# 1468                 14                  3                         4
# 1469                 12                  3                         1
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   1               6                   4
# 1                   3              10                   7
# 2                   3               0                   0
# 3                   3               8                   7
# 4                   3               2                   2
# ...               ...             ...                 ...
# 1465                3               5                   2
# 1466                3               7                   7
# 1467                3               6                   2
# 1468                2               9                   6
# 1469                4               4                   3
#
#       YearsSinceLastPromotion
# 0                           0
# 1                           1
# 2                           0
# 3                           3
# 4                           2
# ...                       ...
# 1465                        0
# 1466                        1
# 1467                        0
# 1468                        0
# 1469                        1
#
# [1470 rows x 10 columns]

# %%
print(df["StockOptionLevel"].value_counts())
plt.figure(figsize=(12,7))
sns.countplot(df["StockOptionLevel"])
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='count'>

# %% [markdown]
# we see that there are four types of data in 'StockOptionLevel' column of our dataframe and class are imbalanced.

# %%
print(df["TotalWorkingYears"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["TotalWorkingYears"])
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %% [markdown]
# we see that most of the TotalWorkingYears of employee is between 3 to 12

# %%
print(df["TrainingTimesLastYear"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["TrainingTimesLastYear"])
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %% [markdown]
# we see that there are 7 types of data in "TrainingTimesLastYear" column of our Dataframe and class are also imbalanced

# %%
print(df["WorkLifeBalance"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["WorkLifeBalance"])
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %% [markdown]
# we see that there are 4 types of data in "WorkLifeBalance" column of our Dataframe and class are also imbalanced

# %%
print(df["YearsAtCompany"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["YearsAtCompany"])
# Out:
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: YearsAtCompany, dtype: int64
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='count'>

# %% [markdown]
# We see that most of the employees in this company are under 10 years of age.class is imbalanced

# %%
print(df["YearsInCurrentRole"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["YearsInCurrentRole"])
# Out:
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: YearsInCurrentRole, dtype: int64
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %%
print(df["YearsSinceLastPromotion"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["YearsSinceLastPromotion"])
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='count'>

# %%
df.iloc[:,30:]
# Out:
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 1 columns]

# %%
print(df["YearsWithCurrManager"].value_counts())
plt.figure(figsize=(20,7))
sns.countplot(df["YearsWithCurrManager"])
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %%
#Checking corelation with each and every column
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# JobLevel                  0.509604  -0.169105        0.019311   0.002966
# JobRole                  -0.122427   0.067151        0.002724  -0.009472
# JobSatisfaction          -0.004892  -0.103481       -0.033962   0.030571
# MaritalStatus            -0.095029   0.162070        0.024001  -0.069586
# MonthlyIncome             0.497855  -0.159840        0.034319   0.007707
# MonthlyRate               0.028051   0.015170       -0.014107  -0.032182
# NumCompaniesWorked        0.299635   0.043494        0.020875   0.038153
# JobInvolvement                 -0.002655                -0.008278  0.017960
# JobLevel                       -0.044933                 0.001212 -0.039403
# JobRole                         0.015599                -0.017321 -0.039723
# JobSatisfaction                -0.034401                -0.006784  0.033252
# MaritalStatus                   0.014420                -0.003593 -0.047183
# MonthlyIncome                  -0.041070                -0.006259 -0.031858
# MonthlyRate                    -0.027182                 0.037600 -0.041482
# NumCompaniesWorked             -0.008663                 0.012594 -0.039147
# OverTime                        0.002259                 0.070132 -0.041924
# PercentSalaryHike              -0.011214                -0.031701  0.002733
# PerformanceRating              -0.005614                -0.029548 -0.013859
# RelationshipSatisfaction       -0.004378                 0.007665  0.022868
# StockOptionLevel               -0.016185                 0.003432  0.012716
# TotalWorkingYears              -0.027848                -0.002693 -0.046881
# TrainingTimesLastYear           0.049195                -0.019359 -0.038787
# WorkLifeBalance                 0.041191                 0.027627 -0.002753
# YearsAtCompany                 -0.018692                 0.001458 -0.029747
# YearsInCurrentRole             -0.010506                 0.018007 -0.041483
# YearsSinceLastPromotion         0.002326                 0.016194 -0.026985
# YearsWithCurrManager           -0.004130                -0.004999 -0.030599
#
#                           ...  PerformanceRating  RelationshipSatisfaction  \
# Age                       ...           0.001904                  0.053535
# Attrition                 ...           0.002889                 -0.045872
# BusinessTravel            ...          -0.026341                 -0.035986
# DailyRate                 ...           0.000473                  0.007846
# Department                ...          -0.024604                 -0.022414
# DistanceFromHome          ...           0.027110                  0.006557
# Education                 ...          -0.024539                 -0.009118
# EducationField            ...          -0.005614                 -0.004378
# EnvironmentSatisfaction   ...          -0.029548                  0.007665
# Gender                    ...          -0.013859                  0.022868
# HourlyRate                ...          -0.002172                  0.001330
# JobInvolvement            ...          -0.029071                  0.034297
# JobLevel                  ...          -0.021222                  0.021642
# JobRole                   ...          -0.024233                 -0.020218
# JobSatisfaction           ...           0.002297                 -0.012454
# MaritalStatus             ...           0.005207                  0.022549
# MonthlyIncome             ...          -0.017120                  0.025873
# MonthlyRate               ...          -0.009811                 -0.004085
# NumCompaniesWorked        ...          -0.014095                  0.052733
# OverTime                  ...           0.004369                  0.048493
# PercentSalaryHike         ...           0.773550                 -0.040490
# PerformanceRating         ...           1.000000                 -0.031351
# RelationshipSatisfaction  ...          -0.031351                  1.000000
# StockOptionLevel          ...           0.003506                 -0.045952
# TotalWorkingYears         ...           0.006744                  0.024054
# TrainingTimesLastYear     ...          -0.015579                  0.002497
# WorkLifeBalance           ...           0.002572                  0.019604
# YearsAtCompany            ...           0.003435                  0.019367
# YearsInCurrentRole        ...           0.034986                 -0.015123
# YearsSinceLastPromotion   ...           0.017896                  0.033493
# YearsWithCurrManager      ...           0.022827                 -0.000867
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.037510           0.680381
# Attrition                        -0.137145          -0.171063
# BusinessTravel                   -0.016727           0.034226
# DailyRate                         0.042143           0.014515
# Department                       -0.012193          -0.015762
# DistanceFromHome                  0.044872           0.004628
# Education                         0.018422           0.148280
# EducationField                   -0.016185          -0.027848
# EnvironmentSatisfaction           0.003432          -0.002693
# Gender                            0.012716          -0.046881
# HourlyRate                        0.050263          -0.002334
# JobInvolvement                    0.021523          -0.005533
# JobLevel                          0.013984           0.782208
# JobRole                          -0.019171          -0.145439
# JobSatisfaction                   0.010690          -0.020185
# MaritalStatus                    -0.662577          -0.077886
# MonthlyIncome                     0.005408           0.772893
# MonthlyRate                      -0.034323           0.026442
# NumCompaniesWorked                0.030075           0.237639
# OverTime                         -0.000449           0.012754
# PercentSalaryHike                 0.007528          -0.020608
# PerformanceRating                 0.003506           0.006744
# RelationshipSatisfaction         -0.045952           0.024054
# StockOptionLevel                  1.000000           0.010136
# TotalWorkingYears                 0.010136           1.000000
# TrainingTimesLastYear             0.011274          -0.035662
# WorkLifeBalance                   0.004129           0.001008
# YearsAtCompany                    0.015058           0.628133
# YearsInCurrentRole                0.050818           0.460365
# YearsSinceLastPromotion           0.014352           0.404858
# YearsWithCurrManager              0.024698           0.459188
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.019621        -0.021490
# Attrition                             -0.059478        -0.063939
# BusinessTravel                         0.015240        -0.011256
# DailyRate                              0.002453        -0.037848
# Department                             0.036875         0.026383
# DistanceFromHome                      -0.036942        -0.026556
# Education                             -0.025100         0.009819
# EducationField                         0.049195         0.041191
# EnvironmentSatisfaction               -0.019359         0.027627
# Gender                                -0.038787        -0.002753
# HourlyRate                            -0.008548        -0.004607
# JobInvolvement                        -0.015338        -0.014617
# JobLevel                              -0.018191         0.037818
# JobRole                                0.001342         0.027764
# JobSatisfaction                       -0.005779        -0.019459
# MaritalStatus                          0.010629         0.014708
# MonthlyIncome                         -0.021736         0.030683
# MonthlyRate                            0.001467         0.007963
# NumCompaniesWorked                    -0.066054        -0.008366
# OverTime                              -0.079113        -0.027092
# PercentSalaryHike                     -0.005221        -0.003280
# PerformanceRating                     -0.015579         0.002572
# RelationshipSatisfaction               0.002497         0.019604
# StockOptionLevel                       0.011274         0.004129
# TotalWorkingYears                     -0.035662         0.001008
# TrainingTimesLastYear                  1.000000         0.028072
# WorkLifeBalance                        0.028072         1.000000
# YearsAtCompany                         0.003569         0.012089
# YearsInCurrentRole                    -0.005738         0.049856
# YearsSinceLastPromotion               -0.002067         0.008941
# YearsWithCurrManager                  -0.004096         0.002759
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.311309            0.212901
# Attrition                      -0.134392           -0.160545
# BusinessTravel                 -0.014575           -0.011497
# DailyRate                      -0.034055            0.009932
# Department                      0.022920            0.056315
# DistanceFromHome                0.009508            0.018845
# Education                       0.069114            0.060236
# EducationField                 -0.018692           -0.010506
# EnvironmentSatisfaction         0.001458            0.018007
# Gender                         -0.029747           -0.041483
# HourlyRate                     -0.019582           -0.024106
# JobInvolvement                 -0.021355            0.008717
# JobLevel                        0.534739            0.389447
# JobRole                        -0.083657           -0.028354
# JobSatisfaction                -0.003803           -0.002305
# MaritalStatus                  -0.059986           -0.065822
# MonthlyIncome                   0.514285            0.363818
# MonthlyRate                    -0.023655           -0.012815
# NumCompaniesWorked             -0.118421           -0.090754
# OverTime                       -0.011687           -0.029758
# PercentSalaryHike              -0.035991           -0.001520
# PerformanceRating               0.003435            0.034986
# RelationshipSatisfaction        0.019367           -0.015123
# StockOptionLevel                0.015058            0.050818
# TotalWorkingYears               0.628133            0.460365
# TrainingTimesLastYear           0.003569           -0.005738
# WorkLifeBalance                 0.012089            0.049856
# YearsAtCompany                  1.000000            0.758754
# YearsInCurrentRole              0.758754            1.000000
# YearsSinceLastPromotion         0.618409            0.548056
# YearsWithCurrManager            0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# Attrition                               -0.033019             -0.156199
# BusinessTravel                          -0.032591             -0.022636
# DailyRate                               -0.033229             -0.026363
# Department                               0.040061              0.034282
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EducationField                           0.002326             -0.004130
# EnvironmentSatisfaction                  0.016194             -0.004999
# Gender                                  -0.026985             -0.030599
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobRole                                 -0.046384             -0.041150
# JobSatisfaction                         -0.018214             -0.027656
# MaritalStatus                           -0.030915             -0.038570
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# OverTime                                -0.012239             -0.041586
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [31 rows x 31 columns]

# %%
#Checking correlation by using heatmap
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Checking skewness
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# we see that maximum columns of the DataFrame present few skewness

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   float64
#  2   BusinessTravel            1470 non-null   float64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   float64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   float64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   float64
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   float64
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   float64
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   float64
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(8), int64(23)
# memory usage: 356.1 KB

# %% [markdown]
# # Checking Skewness Using Distribution Plot

# %%
m=range(0,31)
for i in m:
    plt.figure(figsize=(12,7))
    plt.title(df.columns[i],fontsize=30,color='Blue')
    sns.distplot(df[df.columns[i]])

# %% [markdown]
# # Checking Outliers By Boxplot:

# %%
m=range(0,31)
for i in m:
    plt.figure(figsize=(12,7))
    plt.title(df.columns[i],fontsize=30,color='Blue')
    sns.boxplot(df[df.columns[i]])

# %% [markdown]
# we see that some colmns(Ex.-'Attrition','MonthlyIncome','NumCompaniesWorked','PerformanceRating','StockOptionLavel','TotalWorkingYears','TrainingTimesLastYear'.'YeardAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithcurrManager') present few outliers
# and no outliers present some colmns(Ex.'Age','BuisnessTravel','DailyRate','Department','DistanceFromHome','Education','EducatiomField','EnviromentSatisfatction','gender','HourlyRate','JobInvolvement','Joblevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyRate','OverTime','PercentSalaryHike','RelationSatisfaction','WorklifeBalance','')

# %% [markdown]
# # Remove The Outliers By zscore

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
#            Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     0.446350   2.280906        0.590048   0.742527    1.401512
# 1     1.322365   0.438422        0.913194   1.297775    0.493817
# 2     0.008343   2.280906        0.590048   1.414363    0.493817
# 3     0.429664   0.438422        0.913194   1.461466    0.493817
# 4     1.086676   0.438422        0.590048   0.524295    0.493817
# ...        ...        ...             ...        ...         ...
# 1465  0.101159   0.438422        0.913194   0.202082    0.493817
# 1466  0.227347   0.438422        0.590048   0.469754    0.493817
# 1467  1.086676   0.438422        0.590048   1.605183    0.493817
# 1468  1.322365   0.438422        0.913194   0.546677    1.401512
# 1469  0.320163   0.438422        0.590048   0.432568    0.493817
#
#       DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0             1.010909   0.891688        0.937414                 0.660531
# 1             0.147150   1.868426        0.937414                 0.254625
# 2             0.887515   0.891688        1.316673                 1.169781
# 3             0.764121   1.061787        0.937414                 1.169781
# 4             0.887515   1.868426        0.565311                 1.575686
# ...                ...        ...             ...                      ...
# 1465          1.703764   0.891688        0.565311                 0.254625
# 1466          0.393938   1.868426        0.565311                 1.169781
# 1467          0.640727   0.085049        0.937414                 0.660531
# 1468          0.887515   0.085049        0.565311                 1.169781
# 1469          0.147150   0.085049        0.565311                 0.660531
#
#         Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0     1.224745  ...           0.426230                  1.584178
# 1     0.816497  ...           2.346151                  1.191438
# 2     0.816497  ...           0.426230                  0.658973
# 3     1.224745  ...           0.426230                  0.266233
# 4     0.816497  ...           0.426230                  1.191438
# ...        ...  ...                ...                       ...
# 1465  0.816497  ...           0.426230                  0.266233
# 1466  0.816497  ...           0.426230                  1.584178
# 1467  0.816497  ...           2.346151                  0.658973
# 1468  0.816497  ...           0.426230                  1.191438
# 1469  0.816497  ...           0.426230                  1.584178
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             0.932014           0.421642               2.171982
# 1             0.241988           0.164511               0.155707
# 2             0.932014           0.550208               0.155707
# 3             0.932014           0.421642               0.155707
# 4             0.241988           0.678774               0.155707
# ...                ...                ...                    ...
# 1465          0.241988           0.735447               0.155707
# 1466          0.241988           0.293077               1.707500
# 1467          0.241988           0.678774               2.171982
# 1468          0.932014           0.735447               0.155707
# 1469          0.932014           0.678774               0.155707
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0            2.493820        0.164613            0.063296
# 1            0.338096        0.488508            0.764998
# 2            0.338096        1.144294            1.167687
# 3            0.338096        0.161947            0.764998
# 4            0.338096        0.817734            0.615492
# ...               ...             ...                 ...
# 1465         0.338096        0.327893            0.615492
# 1466         0.338096        0.001333            0.764998
# 1467         0.338096        0.164613            0.615492
# 1468         1.077862        0.325228            0.488900
# 1469         1.754054        0.491174            0.339394
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                    0.679146              0.245834
# 1                    0.368715              0.806541
# 2                    0.679146              1.155935
# 3                    0.252146              1.155935
# 4                    0.058285              0.595227
# ...                       ...                   ...
# 1465                 0.679146              0.314873
# 1466                 0.368715              0.806541
# 1467                 0.679146              0.314873
# 1468                 0.679146              1.086895
# 1469                 0.368715              0.595227
#
# [1470 rows x 31 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([30, 29, 27, 29, 28, 29, 24, 24, 27, 29, 28, 29, 30, 24, 27, 29, 30,
#        29, 24, 30, 27, 28, 29, 28, 30, 27, 29, 24, 27, 28, 29, 29, 30, 24,
#        27, 27, 29, 29, 24, 28, 27, 27, 29, 27, 30, 29, 27, 24, 27, 29, 30,
#        24, 30, 27, 29, 27, 30, 29, 28, 28, 27, 29, 29, 29, 27, 29, 29, 30,
#        24, 27, 29, 27, 29, 29, 30, 29, 24, 27, 28, 29, 29, 28, 24, 29, 30,
#        27, 29, 29, 27, 24, 27, 27, 27, 29, 29, 24, 29, 29, 29, 29, 24, 29,
#        29, 28, 29, 30, 28, 24, 29, 28], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0             2             1.0                        2     0.0  ...
# 1             1             1.0                        3     1.0  ...
# 2             2             4.0                        4     1.0  ...
# 3             4             1.0                        4     0.0  ...
# 4             1             3.0                        1     1.0  ...
# ...         ...             ...                      ...     ...  ...
# 1465          2             3.0                        3     1.0  ...
# 1466          1             3.0                        4     1.0  ...
# 1467          3             1.0                        2     1.0  ...
# 1468          3             3.0                        4     1.0  ...
# 1469          3             3.0                        2     1.0  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1387 rows x 31 columns]

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (1470, 31)
# (1387, 31)

# %% [markdown]
# # checking percentage of dataloss

# %%
percentage_of_dataloss=((8523-8222)/8523)*100
print("percentage of dataloss =",percentage_of_dataloss)
# Out:
# percentage of dataloss = 3.5316203214830457

# %% [markdown]
# # Dividing data in features and Label

# %%
x=df_new.drop("Attrition",axis=1)
y=df_new.iloc[:,1]

# %%
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41             2.0       1102         2.0                 1          2
# 1      49             1.0        279         1.0                 8          1
# 2      37             2.0       1373         1.0                 2          2
# 3      33             1.0       1392         1.0                 3          4
# 4      27             2.0        591         1.0                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36             1.0        884         1.0                23          2
# 1466   39             2.0        613         1.0                 6          1
# 1467   27             2.0        155         1.0                 4          3
# 1468   49             1.0       1023         2.0                 2          3
# 1469   34             2.0        628         1.0                 8          3
#
#       EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0                1.0                        2     0.0          94  ...
# 1                1.0                        3     1.0          61  ...
# 2                4.0                        4     1.0          92  ...
# 3                1.0                        4     0.0          56  ...
# 4                3.0                        1     1.0          40  ...
# ...              ...                      ...     ...         ...  ...
# 1465             3.0                        3     1.0          41  ...
# 1466             3.0                        4     1.0          42  ...
# 1467             1.0                        2     1.0          87  ...
# 1468             3.0                        4     1.0          63  ...
# 1469             3.0                        2     1.0          82  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     3                         1                 0
# 1                     4                         4                 1
# 2                     3                         2                 0
# 3                     3                         3                 0
# 4                     3                         4                 1
# ...                 ...                       ...               ...
# 1465                  3                         3                 1
# 1466                  3                         1                 1
# 1467                  4                         2                 1
# 1468                  3                         4                 0
# 1469                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1387 rows x 30 columns]

# %%
y
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1387, dtype: float64

# %% [markdown]
# # Find multicolinearity by VIF score

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
#define a function to calculate VIF score
def vif_clac():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0    30.937930                       Age
# 1     6.667388            BusinessTravel
# 2     5.041042                 DailyRate
# 3    13.849252                Department
# 4     2.320873          DistanceFromHome
# 5     9.339536                 Education
# 6     3.889948            EducationField
# 7     7.188979   EnvironmentSatisfaction
# 8     2.531225                    Gender
# 9    11.302474                HourlyRate
# 10   15.245642            JobInvolvement
# 11   47.721474                  JobLevel
# 12    8.469352                   JobRole
# 13    7.131744           JobSatisfaction
# 14    5.838069             MaritalStatus
# 15   28.199540             MonthlyIncome
# 16    5.093237               MonthlyRate
# 17    2.704471        NumCompaniesWorked
# 18    1.436858                  OverTime
# 19   42.577573         PercentSalaryHike
# 20  121.885631         PerformanceRating
# 21    7.227946  RelationshipSatisfaction
# 22    3.326677          StockOptionLevel
# 23   12.857933         TotalWorkingYears
# 24    5.737649     TrainingTimesLastYear
# 25   15.675339           WorkLifeBalance
# 26   13.151026            YearsAtCompany
# 27    7.217269        YearsInCurrentRole
# 28    2.161566   YearsSinceLastPromotion
# 29    7.843810      YearsWithCurrManager

# %% [markdown]
# we see that VIF score of "PerformanceRating" column is very high.So,we drop this column.

# %%
#drop 'PerformanceRating' column
x=x.drop(["PerformanceRating"],axis=1)

# %%
x.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41             2.0       1102         2.0                 1          2
# 1   49             1.0        279         1.0                 8          1
# 2   37             2.0       1373         1.0                 2          2
# 3   33             1.0       1392         1.0                 3          4
# 4   27             2.0        591         1.0                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0             1.0                        2     0.0          94  ...
# 1             1.0                        3     1.0          61  ...
# 2             4.0                        4     1.0          92  ...
# 3             1.0                        4     0.0          56  ...
# 4             3.0                        1     1.0          40  ...
#
#    PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# 0                 11                         1                 0
# 1                 23                         4                 1
# 2                 15                         2                 0
# 3                 11                         3                 0
# 4                 12                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 29 columns]

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0    30.106586                       Age
# 1     6.549156            BusinessTravel
# 2     5.016365                 DailyRate
# 3    13.829806                Department
# 4     2.316330          DistanceFromHome
# 5     9.262825                 Education
# 6     3.860926            EducationField
# 7     7.088818   EnvironmentSatisfaction
# 8     2.519747                    Gender
# 9    10.952634                HourlyRate
# 10   14.856745            JobInvolvement
# 11   47.608368                  JobLevel
# 12    8.464027                   JobRole
# 13    7.026455           JobSatisfaction
# 14    5.732649             MaritalStatus
# 15   28.142368             MonthlyIncome
# 16    5.044605               MonthlyRate
# 17    2.703597        NumCompaniesWorked
# 18    1.434128                  OverTime
# 19   16.187031         PercentSalaryHike
# 20    7.120971  RelationshipSatisfaction
# 21    3.292068          StockOptionLevel
# 22   12.815835         TotalWorkingYears
# 23    5.685295     TrainingTimesLastYear
# 24   14.950893           WorkLifeBalance
# 25   13.118905            YearsAtCompany
# 26    7.216363        YearsInCurrentRole
# 27    2.160297   YearsSinceLastPromotion
# 28    7.842498      YearsWithCurrManager

# %% [markdown]
# we see that VIF score of "JobLevel" column is very high.So,we drop this column.

# %%
#drop 'JobLevel' column
x=x.drop(["JobLevel"],axis=1)
x.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41             2.0       1102         2.0                 1          2
# 1   49             1.0        279         1.0                 8          1
# 2   37             2.0       1373         1.0                 2          2
# 3   33             1.0       1392         1.0                 3          4
# 4   27             2.0        591         1.0                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0             1.0                        2     0.0          94  ...
# 1             1.0                        3     1.0          61  ...
# 2             4.0                        4     1.0          92  ...
# 3             1.0                        4     0.0          56  ...
# 4             3.0                        1     1.0          40  ...
#
#    PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# 0                 11                         1                 0
# 1                 23                         4                 1
# 2                 15                         2                 0
# 3                 11                         3                 0
# 4                 12                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 28 columns]

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0    30.024148                       Age
# 1     6.548392            BusinessTravel
# 2     5.014605                 DailyRate
# 3    12.960650                Department
# 4     2.305744          DistanceFromHome
# 5     9.250799                 Education
# 6     3.859693            EducationField
# 7     7.064203   EnvironmentSatisfaction
# 8     2.519183                    Gender
# 9    10.948166                HourlyRate
# 10   14.823179            JobInvolvement
# 11    8.306955                   JobRole
# 12    7.022715           JobSatisfaction
# 13    5.730629             MaritalStatus
# 14    6.993880             MonthlyIncome
# 15    5.041240               MonthlyRate
# 16    2.701228        NumCompaniesWorked
# 17    1.433614                  OverTime
# 18   16.182007         PercentSalaryHike
# 19    7.120072  RelationshipSatisfaction
# 20    3.289270          StockOptionLevel
# 21   12.475248         TotalWorkingYears
# 22    5.682817     TrainingTimesLastYear
# 23   14.857825           WorkLifeBalance
# 24   13.087331            YearsAtCompany
# 25    7.214147        YearsInCurrentRole
# 26    2.160011   YearsSinceLastPromotion
# 27    7.831325      YearsWithCurrManager

# %% [markdown]
# we see that VIF score of "Age" column is very high.So,we drop this column.

# %%
#drop 'Age' column
x=x.drop(["Age"],axis=1)
x.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0             2.0       1102         2.0                 1          2
# 1             1.0        279         1.0                 8          1
# 2             2.0       1373         1.0                 2          2
# 3             1.0       1392         1.0                 3          4
# 4             2.0        591         1.0                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2     0.0          94
# 1             1.0                        3     1.0          61
# 2             4.0                        4     1.0          92
# 3             1.0                        4     0.0          56
# 4             3.0                        1     1.0          40
#
#    JobInvolvement  ...  PercentSalaryHike  RelationshipSatisfaction  \
# 0               3  ...                 11                         1
# 1               2  ...                 23                         4
# 2               2  ...                 15                         2
# 3               3  ...                 11                         3
# 4               3  ...                 12                         4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 27 columns]

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0     6.517981            BusinessTravel
# 1     5.011444                 DailyRate
# 2    12.940878                Department
# 3     2.305420          DistanceFromHome
# 4     8.849522                 Education
# 5     3.858955            EducationField
# 6     7.000784   EnvironmentSatisfaction
# 7     2.515814                    Gender
# 8    10.779752                HourlyRate
# 9    14.553869            JobInvolvement
# 10    8.305863                   JobRole
# 11    6.953554           JobSatisfaction
# 12    5.727119             MaritalStatus
# 13    6.984308             MonthlyIncome
# 14    5.011481               MonthlyRate
# 15    2.658488        NumCompaniesWorked
# 16    1.430863                  OverTime
# 17   15.781123         PercentSalaryHike
# 18    7.037302  RelationshipSatisfaction
# 19    3.276780          StockOptionLevel
# 20    9.679879         TotalWorkingYears
# 21    5.646556     TrainingTimesLastYear
# 22   14.768216           WorkLifeBalance
# 23   13.062451            YearsAtCompany
# 24    7.206903        YearsInCurrentRole
# 25    2.158445   YearsSinceLastPromotion
# 26    7.830134      YearsWithCurrManager

# %% [markdown]
# we see that VIF score of "PercentSalaryHike" column is very high.So,we drop this column

# %%
#drop 'PercentSalaryHike' column
x=x.drop(["PercentSalaryHike"],axis=1)
x.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0             2.0       1102         2.0                 1          2
# 1             1.0        279         1.0                 8          1
# 2             2.0       1373         1.0                 2          2
# 3             1.0       1392         1.0                 3          4
# 4             2.0        591         1.0                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2     0.0          94
# 1             1.0                        3     1.0          61
# 2             4.0                        4     1.0          92
# 3             1.0                        4     0.0          56
# 4             3.0                        1     1.0          40
#
#    JobInvolvement  ...  OverTime  RelationshipSatisfaction  StockOptionLevel  \
# 0               3  ...       1.0                         1                 0
# 1               2  ...       0.0                         4                 1
# 2               2  ...       1.0                         2                 0
# 3               3  ...       1.0                         3                 0
# 4               3  ...       0.0                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 26 columns]

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0     6.479884            BusinessTravel
# 1     4.961941                 DailyRate
# 2    12.938621                Department
# 3     2.290937          DistanceFromHome
# 4     8.771449                 Education
# 5     3.848946            EducationField
# 6     6.963297   EnvironmentSatisfaction
# 7     2.504202                    Gender
# 8    10.643943                HourlyRate
# 9    14.333934            JobInvolvement
# 10    8.291988                   JobRole
# 11    6.850552           JobSatisfaction
# 12    5.635738             MaritalStatus
# 13    6.984113             MonthlyIncome
# 14    4.986516               MonthlyRate
# 15    2.656753        NumCompaniesWorked
# 16    1.430023                  OverTime
# 17    7.015833  RelationshipSatisfaction
# 18    3.245087          StockOptionLevel
# 19    9.677781         TotalWorkingYears
# 20    5.611850     TrainingTimesLastYear
# 21   14.447634           WorkLifeBalance
# 22   13.061436            YearsAtCompany
# 23    7.206884        YearsInCurrentRole
# 24    2.157100   YearsSinceLastPromotion
# 25    7.821430      YearsWithCurrManager

# %% [markdown]
# we see that VIF score of "WorkLifeBalance" column is very high.So,we drop this column

# %%
#drop 'WorkLifeBalance' column
x=x.drop(["WorkLifeBalance"],axis=1)
x.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0             2.0       1102         2.0                 1          2
# 1             1.0        279         1.0                 8          1
# 2             2.0       1373         1.0                 2          2
# 3             1.0       1392         1.0                 3          4
# 4             2.0        591         1.0                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2     0.0          94
# 1             1.0                        3     1.0          61
# 2             4.0                        4     1.0          92
# 3             1.0                        4     0.0          56
# 4             3.0                        1     1.0          40
#
#    JobInvolvement  ...  NumCompaniesWorked  OverTime  \
# 0               3  ...                   8       1.0
# 1               2  ...                   1       0.0
# 2               2  ...                   6       1.0
# 3               3  ...                   1       1.0
# 4               3  ...                   9       0.0
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                      0               6                   4
# 1                      3              10                   7
# 2                      3               0                   0
# 3                      3               8                   7
# 4                      3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 25 columns]

# %%
#checking VIF score
vif_clac()
# Out:
#     VIF Factor                  features
# 0     6.443311            BusinessTravel
# 1     4.960040                 DailyRate
# 2    12.903529                Department
# 3     2.290861          DistanceFromHome
# 4     8.670585                 Education
# 5     3.813708            EducationField
# 6     6.847724   EnvironmentSatisfaction
# 7     2.493878                    Gender
# 8    10.496939                HourlyRate
# 9    14.073107            JobInvolvement
# 10    8.284602                   JobRole
# 11    6.808208           JobSatisfaction
# 12    5.537289             MaritalStatus
# 13    6.971801             MonthlyIncome
# 14    4.954762               MonthlyRate
# 15    2.654131        NumCompaniesWorked
# 16    1.429873                  OverTime
# 17    6.920853  RelationshipSatisfaction
# 18    3.207491          StockOptionLevel
# 19    9.677281         TotalWorkingYears
# 20    5.543281     TrainingTimesLastYear
# 21   13.048073            YearsAtCompany
# 22    7.199875        YearsInCurrentRole
# 23    2.156809   YearsSinceLastPromotion
# 24    7.815582      YearsWithCurrManager

# %%
x.skew()
# Out:
# DailyRate            -0.017078
# MonthlyIncome         1.544770
# MonthlyRate           0.030596
# NumCompaniesWorked    1.037715
# OverTime              0.954751
#                         ...
# JobSatisfaction_3     0.866706
# JobSatisfaction_4     0.789862
# MaritalStatus_0.0     1.359116
# MaritalStatus_1.0     0.166579
# MaritalStatus_2.0     0.761376
# Length: 156, dtype: float64

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 0.75061538,  0.38667413,  0.75597403, ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        [-1.34337244,  0.14423538,  1.41099114, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [ 1.33708042, -1.4311531 , -1.91003533, ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        ...,
#        [-1.75453754,  0.42420987, -1.34292063, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [ 0.57328582,  0.22222847, -0.06793172, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [-0.37222758, -0.10193019, -0.50641407, ..., -0.52981294,
#          1.08665432, -0.68958822]])

# %%
#print skewness after power transform
df_new1=pd.DataFrame(x)
df_new1.skew()
# Out:
# 0     -0.199742
# 1      0.027700
# 2     -0.176560
# 3      0.016175
# 4      0.954751
#          ...
# 151    0.866706
# 152    0.789862
# 153    1.359116
# 154    0.166579
# 155    0.761376
# Length: 156, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.75061538,  0.38667413,  0.75597403, ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        [-1.34337244,  0.14423538,  1.41099114, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [ 1.33708042, -1.4311531 , -1.91003533, ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        ...,
#        [-1.75453754,  0.42420987, -1.34292063, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [ 0.57328582,  0.22222847, -0.06793172, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [-0.37222758, -0.10193019, -0.50641407, ..., -0.52981294,
#          1.08665432, -0.68958822]])

# %%
#print skewness after power transform
df_new2=pd.DataFrame(x)
df_new2.skew()
# Out:
# 0     -0.199742
# 1      0.027700
# 2     -0.176560
# 3      0.016175
# 4      0.954751
#          ...
# 151    0.866706
# 152    0.789862
# 153    1.359116
# 154    0.166579
# 155    0.761376
# Length: 156, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
trainx,trainy=smt.fit_resample(x,y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, RandomizedSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
#finding best random state
maxAccu=0
maxRS=0
for i in range(1,1400):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.3,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=accuracy_score(y_test,predlr)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy score is :",maxAccu,"on random state  ",maxRS)
# Out:
# Best accuracy score is : 0.8733812949640288 on random state   1191

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.3,random_state =1191)

# %%
x_train
# Out:
# array([[-1.01006874, -2.51534653,  0.73113702, ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        [ 0.88323078,  1.36840166,  0.46939695, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [ 1.58546624,  1.17178897,  1.59977787, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        ...,
#        [ 0.32767115,  0.52040268,  1.1880517 , ..., -0.52981294,
#         -0.92025586,  1.45014078],
#        [ 0.86344671, -0.13168584,  0.53468357, ..., -0.52981294,
#          1.08665432, -0.68958822],
#        [-1.16738148, -0.9638713 , -1.45702652, ..., -0.52981294,
#         -0.92025586,  1.45014078]])

# %%
x_test
# Out:
# array([[-2.73478197e-01, -2.30442456e+00,  3.28254488e-01, ...,
#         -5.29812943e-01, -9.20255855e-01,  1.45014078e+00],
#        [-1.59840990e+00,  1.03768297e+00,  8.14014875e-01, ...,
#         -5.29812943e-01, -9.20255855e-01,  1.45014078e+00],
#        [ 1.82560655e-01,  5.58745966e-01,  5.14553982e-01, ...,
#         -5.29812943e-01,  1.08665432e+00, -6.89588221e-01],
#        ...,
#        [-2.20889700e-01,  1.44544535e-01, -6.65538084e-01, ...,
#          1.88745861e+00, -9.20255855e-01, -6.89588221e-01],
#        [ 1.47836728e-03,  1.30385994e+00,  7.67067624e-01, ...,
#         -5.29812943e-01,  4.24741413e-01,  1.61305790e-02],
#        [-5.32009799e-02, -1.35527010e+00, -6.72096638e-01, ...,
#         -5.29812943e-01, -9.20255855e-01,  1.45014078e+00]])

# %%
y_train
# Out:
# 23      0.0
# 1339    0.0
# 740     0.0
# 424     0.0
# 1832    1.0
#        ...
# 358     1.0
# 641     0.0
# 236     0.0
# 79      0.0
# 1198    1.0
# Name: Attrition, Length: 1621, dtype: float64

# %%
y_test
# Out:
# 953     1.0
# 944     0.0
# 1451    1.0
# 797     0.0
# 1222    0.0
#        ...
# 312     0.0
# 1191    0.0
# 1357    0.0
# 2310    1.0
# 337     1.0
# Name: Attrition, Length: 695, dtype: float64

# %%
print("x_train shape =",x_train.shape)
print("x_test shape =",x_test.shape)
print("y_train shape =",y_train.shape)
print("y_test shape =",y_test.shape)
# Out:
# x_train shape = (1621, 156)
# x_test shape = (695, 156)
# y_train shape = (1621,)
# y_test shape = (695,)

# %% [markdown]
# # Logistic Regression

# %%
lg=LogisticRegression()
gnb=GaussianNB()
svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
rfc=RandomForestClassifier()

# %%
model=[lg,gnb,svc,dtc,knn,rfc]

# %%
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of ',m,'is')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of  LogisticRegression() is
# 0.8733812949640288
# [[295  46]
#  [ 42 312]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87       341
#          1.0       0.87      0.88      0.88       354
#
#     accuracy                           0.87       695
#    macro avg       0.87      0.87      0.87       695
# weighted avg       0.87      0.87      0.87       695
#
#
#
# Accuracy score of  GaussianNB() is
# 0.679136690647482
# [[139 202]
#  [ 21 333]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.41      0.55       341
#          1.0       0.62      0.94      0.75       354
#
#     accuracy                           0.68       695
#    macro avg       0.75      0.67      0.65       695
# weighted avg       0.74      0.68      0.65       695
#
#
#
# Accuracy score of  SVC() is
# 0.9712230215827338
# [[331  10]
#  [ 10 344]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       341
#          1.0       0.97      0.97      0.97       354
#
#     accuracy                           0.97       695
#    macro avg       0.97      0.97      0.97       695
# weighted avg       0.97      0.97      0.97       695
#
#
#
# Accuracy score of  DecisionTreeClassifier() is
# 0.8474820143884892
# [[294  47]
#  [ 59 295]]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.86      0.85       341
#          1.0       0.86      0.83      0.85       354
#
#     accuracy                           0.85       695
#    macro avg       0.85      0.85      0.85       695
# weighted avg       0.85      0.85      0.85       695
#
#
#
# Accuracy score of  KNeighborsClassifier() is
# 0.7597122302158273
# [[185 156]
#  [ 11 343]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.54      0.69       341
#          1.0       0.69      0.97      0.80       354
#
#     accuracy                           0.76       695
#    macro avg       0.82      0.76      0.75       695
# weighted avg       0.81      0.76      0.75       695
#
#
#
# Accuracy score of  RandomForestClassifier() is
# 0.9381294964028777
# [[339   2]
#  [ 41 313]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.99      0.94       341
#          1.0       0.99      0.88      0.94       354
#
#     accuracy                           0.94       695
#    macro avg       0.94      0.94      0.94       695
# weighted avg       0.94      0.94      0.94       695

# %%
#cross validation of the model
from sklearn.model_selection import cross_val_score
for m in model:
    scr=cross_val_score(m,x,y,cv=5)
    print("cross validation score of",m,"is =",scr.mean())
# Out:
# cross validation score of LogisticRegression() is = 0.8572630704100981
# cross validation score of GaussianNB() is = 0.3388307404617822
# cross validation score of SVC() is = 0.845713321039919
# cross validation score of DecisionTreeClassifier() is = 0.78874892865491
# cross validation score of KNeighborsClassifier() is = 0.8175960314780667
# cross validation score of RandomForestClassifier() is = 0.8507544866633768

# %% [markdown]
# Parameter Tuning for RandomForestClassifier

# %%
#creating parameter list to pass in GreadSearchCV
parameters={'max_features':['auto','sqrt','log2'],'max_depth':[4,5,6,7,8],'criterion':['gini','entropy']}
gcv1=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
gcv1.fit(x_train,y_train)
gcv1.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt'}

# %%
gcv1.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8)

# %%
gcvpred1=gcv1.best_estimator_.predict(x_test)
accuracy_score(y_test,gcvpred1)
# Out:
# 0.9410071942446043

# %%
scr1=cross_val_score(gcv1.best_estimator_,x,y,cv=5)
print("cross validation score of",m,"is =",scr1.mean())
# Out:
# cross validation score of RandomForestClassifier() is = 0.8421058099368881

# %% [markdown]
# #

# %% [markdown]
# # Accuracy Score For Training data:

# %%
gcvpred1=gcv1.best_estimator_.predict(x_train)
accuracy_score(y_train,gcvpred1)
# Out:
# 0.9623689080814312

# %%
final_model=RandomForestClassifier(max_depth=8, max_features='sqrt')

# %%
final_model.fit(x_train,y_train)
predm1=final_model.predict(x_test)
predm2=final_model.predict(x_train)
print('Test Accuracy score of final model =',accuracy_score(y_test,predm1))
print('Test Accuracy score of final model =',accuracy_score(y_train,predm2))
print(confusion_matrix(y_test,predm))
print(classification_report(y_test,predm))
# Out:
# Test Accuracy score of final model = 0.9381294964028777
# Test Accuracy score of final model = 0.9691548426896978
# [[339   2]
#  [ 41 313]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.99      0.94       341
#          1.0       0.99      0.88      0.94       354
#
#     accuracy                           0.94       695
#    macro avg       0.94      0.94      0.94       695
# weighted avg       0.94      0.94      0.94       695

# %% [markdown]
# # ROCAUC curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=lg.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([9.63453467e-01, 5.07579531e-01, 6.26122878e-01, 2.62268446e-01,
#        9.54573818e-01, 6.94529060e-01, 9.32358540e-01, 4.09315662e-01,
#        9.50329590e-01, 9.92095242e-01, 5.72035775e-02, 2.68341879e-01,
#        8.74474345e-01, 8.66671315e-04, 2.65437114e-02, 1.87517103e-01,
#        6.30313729e-01, 5.51489014e-01, 8.15724296e-03, 9.85027309e-01,
#        8.76237744e-01, 1.87078271e-01, 8.48170350e-02, 6.97463356e-03,
#        0.12316716, 0.12316716, 0.12609971, 0.12609971, 0.13489736,
#        0.13489736, 0.14369501, 0.14369501, 0.14662757, 0.14662757,
#        0.14956012, 0.14956012, 0.15249267, 0.15249267, 0.15542522,
#        0.15542522, 0.15835777, 0.15835777, 0.16129032, 0.16129032,
#        0.16715543, 0.16715543, 0.17008798, 0.17008798, 0.17302053,
#        0.17302053, 0.18768328, 0.18768328, 0.2228739 , 0.2228739 ,
#        0.228739  , 0.228739  , 0.24046921, 0.24046921, 0.25513196,
#        0.25513196, 0.26099707, 0.26099707, 0.27859238, 0.27859238,
#        0.30791789, 0.30791789, 0.38123167, 0.38123167, 0.43695015,
#        0.43695015, 0.45454545, 0.45454545, 0.49266862, 0.49266862,
#        1.        ])

# %%
tpr
# Out:
# array([0.        , 0.00282486, 0.03107345, 0.03107345, 0.08757062,
#        0.08757062, 0.0960452 , 0.0960452 , 0.11299435, 0.11299435,
#        0.13559322, 0.13559322, 0.14971751, 0.14971751, 0.29378531,
#        0.29378531, 0.34463277, 0.34463277, 0.35875706, 0.35875706,
#        0.37853107, 0.37853107, 0.38418079, 0.38418079, 0.5       ,
#        0.5       , 0.53672316, 0.53672316, 0.5480226 , 0.5480226 ,
#        0.55084746, 0.55084746, 0.56497175, 0.56497175, 0.57627119,
#        0.57627119, 0.59887006, 0.59887006, 0.62146893, 0.62146893,
#        0.64124294, 0.64124294, 0.6440678 , 0.6440678 , 0.64971751,
#        0.64971751, 0.66101695, 0.66101695, 0.68926554, 0.68926554,
#        0.69774011, 0.69774011, 0.75423729, 0.75423729, 0.77118644,
#        0.77118644, 0.78248588, 0.78248588, 0.78813559, 0.78813559,
#        0.80508475, 0.80508475, 0.81638418, 0.81638418, 0.82768362,
#        0.82768362, 0.83615819, 0.83615819, 0.85028249, 0.85028249,
#        0.8559322 , 0.8559322 , 0.86158192, 0.86158192, 0.86440678,
#        0.86440678, 0.87288136, 0.87288136, 0.88135593, 0.88135593,
#        0.88700565, 0.88700565, 0.88983051, 0.88983051, 0.89830508,
#        0.89830508, 0.90112994, 0.90112994, 0.91242938, 0.91242938,
#        0.91525424, 0.91525424, 0.92655367, 0.92655367, 0.92937853,
#        0.92937853, 0.94632768, 0.94632768, 0.94915254, 0.94915254,
#        0.9519774 , 0.9519774 , 0.95480226, 0.95480226, 0.96327684,
#        0.96327684, 0.96892655, 0.96892655, 0.97457627, 0.97457627,
#        0.98022599, 0.98022599, 0.98305085, 0.98305085, 0.98587571,
#        0.98587571, 0.98870056, 0.98870056, 0.99152542, 0.99152542,
#        0.99435028, 0.99435028, 0.99717514, 0.99717514, 1.        ,
#        1.        ])

# %%
auc_score=roc_auc_score(y_test,final_model.predict(x_test))

# %%
auc_score
# Out:
# 0.938996305316699

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROCAUC Curve',color='Blue',size=30)
plt.show()

# %%
#Save the final model                                                                      
import joblib                                                                                                     
joblib.dump(final_model,'HR Analytics Project Model.pkl')
# Out:
# ['HR Analytics Project Model.pkl']

# %% [markdown]
# # Thankyou For watching my project
